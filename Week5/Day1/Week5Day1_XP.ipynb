# %% [markdown]
# 🌟 Exercise 1 : Understanding Data Visualization
#
# Instructions
#
# Explain why data visualization is important in data analysis.
# Describe the purpose of a line graph in data visualization.
#
#
# 1. For most of us (people), visibility is the main factor of understanding. We tend to trust what we see. And the clearer the subject of our observation becomes, the easier it will be for us to draw appropriate conclusions and discoveries. By visualizing the processed data, it is much easier to come to the right conclusions (there is less chance that the bias error will affect), in addition, focusing on visual graphs, it is much easier to pitch information to stakeholders
#
#
# 2. The purpose of line graph is to show the tendention of quantative changing during the time

# %% [markdown]
# 🌟 Exercise 2 : Creating a Line Plot for Temperature Variation
# Instructions
#
# Create a simple line plot using Matplotlib that represents the temperature variations over a week.
#
# Use a list of temperature values for each day of the week (e.g., [72, 74, 76, 80, 82, 78, 75]) and label the x-axis as “Day” and the y-axis as “Temperature (°F)”.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
plt.style.use('dark_background')

# %%
temp = [72, 74, 76, 80, 82, 78, 75]
day = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

plt.plot(day, temp)
plt.xlabel('Day')
plt.ylabel('Temperature (°F)')
plt.title('Temperature Variation')
plt.show()

# %% [markdown]
# 🌟 Exercise 3 : Visualizing Monthly Sales with a Bar Chart
# Instructions
#
# Generate a bar chart using Matplotlib to visualize the monthly sales data for a retail store.
#
# Create a list of sales values for each month (e.g., [5000, 5500, 6200, 7000, 7500]) and label the x-axis as “Month” and the y-axis as “Sales Amount ($)”.

# %%
month_sales = [5000, 5500, 6200, 7000, 7500]
month = ['January', 'February', 'March', 'April', 'May']

plt.bar(month, month_sales, color = 'pink')
plt.xlabel('Month')
plt.ylabel('Sales Amount ($)')
plt.title('Monthly Sales')
plt.show()

# %% [markdown]
# 🌟 Exercise 4 : Data Visualisation
#
# Instructions
#
# Using the dataset: sales_data.csv
#
# Calculate the total quantity of products sold by the company.
#
# Identify the category that had the highest revenue and calculate how much revenue it generated.
#
# Determine the average revenue per sale in the dataset. **(Electronics	)**
#
# Create a bar chart to visualize the total revenue generated in each quarter of the year (Q1, Q2, Q3, Q4).

# %%
df = pd.read_csv('sales_data.csv')
df.head()
# Out:
#          date     product     category   price  quantity  revenue
# 0  2022-01-01  Smartphone  Electronics   600.0      10.0   6000.0
# 1  2022-01-01      Laptop  Electronics  1200.0       5.0   6000.0
# 2  2022-01-02     T-Shirt     Clothing    20.0      50.0   1000.0
# 3  2022-01-03  Headphones  Electronics   100.0      20.0   2000.0
# 4  2022-01-04     T-Shirt     Clothing    20.0      25.0    500.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 369 entries, 0 to 368
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      369 non-null    object
#  1   product   369 non-null    object
#  2   category  369 non-null    object
#  3   price     367 non-null    float64
#  4   quantity  368 non-null    float64
#  5   revenue   368 non-null    float64
# dtypes: float64(3), object(3)
# memory usage: 17.4+ KB

# %%
df['quantity'].sum()
# Out:
# 5360.0

# %%
df.groupby('category')['revenue'].sum().sort_values(ascending = False)
# Out:
# category
# Electronics    516080.0
# Accessories    104700.0
# Clothing        94350.0
# Shoes           20640.0
# Bags            19500.0
# Clohting         1200.0
# Shoeses           960.0
# Bgas              900.0
# Name: revenue, dtype: float64

# %%
df['revenue'].sum()/df['quantity'].sum() #mean of 1 item
# Out:
# 141.4794776119403

# %%
df['revenue'].sum()/368   #368 - number of known sales # - Mean revenue
# Out:
# 2060.679347826087

# %%
df['date'] = pd.to_datetime(df['date'])
df['quarter'] = df['date'].dt.quarter
df.head()
# Out:
#         date     product     category   price  quantity  revenue  quarter
# 0 2022-01-01  Smartphone  Electronics   600.0      10.0   6000.0        1
# 1 2022-01-01      Laptop  Electronics  1200.0       5.0   6000.0        1
# 2 2022-01-02     T-Shirt     Clothing    20.0      50.0   1000.0        1
# 3 2022-01-03  Headphones  Electronics   100.0      20.0   2000.0        1
# 4 2022-01-04     T-Shirt     Clothing    20.0      25.0    500.0        1

# %%
df['quarter'].unique()
# Out:
# array([1, 2, 3, 4], dtype=int32)

# %%
sum_quarters = df.groupby('quarter')['revenue'].sum().tolist()
# Out:
# [quarter
#  1    182100.0
#  2    183970.0
#  3    197680.0
#  4    194580.0
#  Name: revenue, dtype: float64]

# %%
quaters = [1,2,3,4]
plt.bar(quaters, sum_quarters ,color = 'blue' )

plt.xlabel('Quarter')
plt.ylabel('Revenue')
plt.xticks( ticks = quaters ,labels=['Q1', 'Q2', 'Q3', 'Q4'])

plt.title('Revenue by Quarter')
plt.show()

# %% [markdown]
# 🌟 Exercise 5 : Data Visualisation Using MatPlotLib
#
# Instructions
#
# Create a simple line plot using Matplotlib. Plot the function y = x^2 for x values ranging from -10 to 10. Add a title and label the x and y axes.
#
# Generate a bar chart to display the sales data of four different products (A, B, C, D) in a week. The sales values are 15, 30, 45, and 20 respectively. Label the chart appropriately.
#
# Create a pie chart representing the following data about favorite fruits of a group of people: Apples (40%), Bananas (30%), Cherries (20%), and Dates (10%). Customize the chart with different colors for each fruit and add a legend.

# %%
x = range(-10,11)
y = [i**2 for i in x]
plt.plot(x,y)
plt.title('y = x^2')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
products = ['A', 'B', 'C', 'D']
sales = [15, 30, 45, 20]
plt.bar(products, sales, color = 'orange')
plt.xlabel('Products')
plt.ylabel('Sales')
plt.title('Sales Data')
plt.show()

# %%
data = {'Apples': 40, 'Bananas': 30, 'Cherries': 20, 'Dates': 10}

plt.pie(data.values(), labels=data.keys(), colors=['green', 'yellow', 'red', 'blue'], autopct='%1.1f%%')
plt.title('Favorite Fruits')
# Out:
# Text(0.5, 1.0, 'Favorite Fruits')
